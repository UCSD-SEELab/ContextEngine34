# %% [markdown]
# https://datamarket.com/data/set/235e/hveravellir-1-jan-1972-31-dec-1974-daily-temperature-degrees-centigrade#!ds=235e&display=line

# %%
import csv
import os

# %%
data = []
with open('hveravellir-1-jan-1972-31-dec-19.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    
    for row in spamreader:
        temp = (row[0].split(','))
        temp[1] = float(temp[1].replace("?", "-"))
        data.append(temp)
#         print(temp)

# %%
data40 = []
for i in os.listdir("./pfData"):
    if i.endswith(".csv") : 
        dataArray = []
        with open("./pfData/"+i, newline='') as csvfile:
            spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')

            for row in spamreader:
                temp = (row[0].split(','))
                temp[1] = float(temp[1].replace("?", "-"))
                dataArray.append(temp[1])
        data40.append(dataArray)
        continue
    else:
        continue

# %%
data40Var = []
for i in os.listdir("./pfData/new36Variance"):
    if i.endswith(".csv") : 
        dataArray = []
        with open("./pfData/new36Variance/"+i, newline='') as csvfile:
            spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')

            for row in spamreader:
                temp = (row[0].split(','))
                temp[1] = float(temp[1].replace("?", "-"))
                dataArray.append(temp[1])
        data40Var.append(dataArray)
        continue
    else:
        continue

# %%
data40Var50 = []
for i in os.listdir("./pfData/50Var"):
    if i.endswith(".csv") : 
        dataArray = []
        with open("./pfData/50Var/"+i, newline='') as csvfile:
            spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')

            for row in spamreader:
                temp = (row[0].split(','))
                temp[1] = float(temp[1].replace("?", "-"))
                dataArray.append(temp[1])
        data40Var50.append(dataArray)
        continue
    else:
        continue

# %%
data40Var100 = []
for i in os.listdir("./pfData/100Var"):
    if i.endswith(".csv") : 
        dataArray = []
        with open("./pfData/100Var/"+i, newline='') as csvfile:
            spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')

            for row in spamreader:
                temp = (row[0].split(','))
                temp[1] = float(temp[1].replace("?", "-"))
                dataArray.append(temp[1])
        data40Var100.append(dataArray)
        continue
    else:
        continue

# %%
data60 = []
for i in os.listdir("./pfData/60Percent"):
    if i.endswith(".csv") : 
        dataArray = []
        with open("./pfData/60Percent/"+i, newline='') as csvfile:
            spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')

            for row in spamreader:
                temp = (row[0].split(','))
                temp[1] = float(temp[1].replace("?", "-"))
                dataArray.append(temp[1])
        data60.append(dataArray)
        continue
    else:
        continue

# %%
data80 = []
for i in os.listdir("./pfData/80Percent"):
    if i.endswith(".csv") : 
        dataArray = []
        with open("./pfData/80Percent/"+i, newline='') as csvfile:
            spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')

            for row in spamreader:
                temp = (row[0].split(','))
                temp[1] = float(temp[1].replace("?", "-"))
                dataArray.append(temp[1])
        data80.append(dataArray)
        continue
    else:
        continue

# %%
len(data60)
# Out:
# 3

# %%
y = []
x= []
count = 0
for i in data:
    y.append(i[1])
    x.append(count)
    count+=1

# %%
len(x)*.60
# Out:
# 657.0

# %%
xSample60 = np.unique(np.sort(np.random.randint(1095, size=1000)))
len(xSample60)
# Out:
# 657

# %%
xS =[]
ySample60 = []
for index in xSample60:
    ySample60.append(y[index])

# %%
np.var(y)**(1/2),np.mean(y)
# Out:
# (6.0209471465201982, -0.44191780821917803)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 20, 6

rcParams.update({'font.size': 16})



plt.title('Original Dataset')
# plt.scatter(x, y, s=area, alpha=0.5)
plt.xlabel("Days")
plt.ylabel("Temperture Celsius")
plt.plot(x, y)
plt.savefig('Hveravellir_Regular.png')
plt.show()


plt.title('SIR Unit Interpolation 40% of Dataset,p=100 new Variance')
# plt.scatter(x, y, s=area, alpha=0.5)
plt.xlabel("Days")
plt.ylabel("Temperture Celsius")
plt.plot(x, data40Var[0])
plt.savefig('H_40P_100.png')
plt.show()


plt.title('SIR Unit Interpolation 40% of Dataset,p=1000 new Variance')
# plt.scatter(x, y, s=area, alpha=0.5)
plt.xlabel("Days")
plt.ylabel("Temperture Celsius")
plt.plot(x, data40Var[1])
plt.savefig('H_40P_1000.png')
plt.show()


plt.title('SIR Unit Interpolation 40% of Dataset,p=10000 new Variance')
# plt.scatter(x, y, s=area, alpha=0.5)
plt.xlabel("Days")
plt.ylabel("Temperture Celsius")
plt.plot(x, data40Var[2])
plt.savefig('H_40P_10000.png')
plt.show()

plt.title('SIR Unit Interpolation 60% of Dataset,p=1000 new Variance')
# plt.scatter(x, y, s=area, alpha=0.5)
plt.xlabel("Days")
plt.ylabel("Temperture Celsius")
plt.plot(x, data60[1])
plt.savefig('H_60P_1000.png')
plt.show()

plt.title('SIR Unit Interpolation 80% of Dataset,p=1000 new Variance')
# plt.scatter(x, y, s=area, alpha=0.5)
plt.xlabel("Days")
plt.ylabel("Temperture Celsius")
plt.plot(x, data80[1])
plt.savefig('H_80P_1000.png')
plt.show()

# %%
for a in data40Var:
    npPY = np.asarray(a)
    ax = None
    mse1k = ((y - npPY) ** 2).mean(axis=ax)
    print("40 Percent",mse1k**(1/2))

for a in data60:
    npPY = np.asarray(a)
    ax = None
    mse1k = ((y - npPY) ** 2).mean(axis=ax)
    print("60 Percent",mse1k**(1/2))
for a in data80:
    npPY = np.asarray(a)
    ax = None
    mse1k = ((y - npPY) ** 2).mean(axis=ax)
    print("80 Percent",mse1k**(1/2))
# Out:
# 40 Percent 2.66909686728
# 40 Percent 2.67027911104
# 40 Percent 2.6684080825
# 60 Percent 2.44012036152
# 60 Percent 2.43985193913
# 60 Percent 2.43671350582
# 80 Percent 2.59270457546
# 80 Percent 2.59334745461
# 80 Percent 2.58722544602

# %%
import csv
yS = []
with open('data60.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=' ',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for index in xSample60:
        spamwriter.writerow([index, y[index]])
        yS.append(y[index])

# %% [raw]
# 100
# 40
# The Set Move Set Ex Time 3e-06
# The Initialise Ex Time 0.000456
# Iter Ave 0.00108362
# Itegrate Ave 0.000153437
# 60
# The Set Move Set Ex Time 4e-06
# The Initialise Ex Time 0.000438
# Iter Ave 0.000745645
# Itegrate Ave 0.000105808
# 80
# The Set Move Set Ex Time 2e-06
# The Initialise Ex Time 0.000387
# Iter Ave 0.000544708
# Itegrate Ave 7.71708e-05
#
# 1000
# 40
# The Set Move Set Ex Time 3e-06
# The Initialise Ex Time 0.002176
# Iter Ave 0.0108605
# Itegrate Ave 0.00150831
# 60
# The Set Move Set Ex Time4e-06
# The Initialise Ex Time 0.002218
# Iter Ave 0.0074851
# Itegrate Ave 0.00103604
# 80
# The Set Move Set Ex Time3e-06
# The Initialise Ex Time0.002248
# Iter Ave0.00547453
# Itegrate Ave0.000757637
#
# 10000
# 40
# The Set Move Set Ex Time6e-06
# The Initialise Ex Time 0.019491
# Iter Ave 0.111
# Itegrate Ave 0.0151264
# 60
# The Set Move Set Ex Time5e-06
# The Initialise Ex Time 0.019456
# Iter Ave 0.0765035
# Itegrate Ave 0.0104251
# 80
# The Set Move Set Ex Time4e-06
# The Initialise Ex Time 0.019502
# Iter Ave 0.0559044
# Itegrate Ave 0.00762606
#
# With A+
# 100
# 40
# The Set Move Set Ex Time5e-06
# The Initialise Ex Time0.000628
# Iter Ave 0.00150886
# Itegrate Ave0.000119781
# 60
# The Set Move Set Ex Time6e-06
# The Initialise Ex Time0.000766
# Iter Ave0.0012232
# Itegrate Ave0.000174732
# 80
# The Set Move Set Ex Time6e-06
# The Initialise Ex Time 0.00095
# Iter Ave 0.000834677
# Itegrate Ave 0.00012141
#
# 1000
# 40
# The Set Move Set Ex Time 6e-06
# The Initialise Ex Time 0.005149
# Iter Ave 0.0161127
# Itegrate Ave 0.00252162
# 60
# The Set Move Set Ex Time 5e-06
# The Initialise Ex Time 0.004736
# Iter Ave 0.0109085
# Itegrate Ave 0.00172483
# 80
# The Set Move Set Ex Time 6e-06
# The Initialise Ex Time 0.003668
# Iter Ave 0.00854578
# Itegrate Ave 0.00126874
#
# 10,000
# 40
# The Set Move Set Ex Time 6e-06
# The Initialise Ex Time 0.034993
# Iter Ave 0.173282
# Itegrate Ave 0.0285618
# 60
# The Set Move Set Ex Time6e-06
# The Initialise Ex Time0.031999
# Iter Ave0.119037
# Itegrate Ave0.0195831
# 80
# The Set Move Set Ex Time6e-06
# The Initialise Ex Time0.031736
# Iter Ave0.0874775
# Itegrate Ave0.0143195

# %%
pi2_1000par_Iterate = [0.0108605,0.0074851,0.00547453]
pi2_1000par_Integrate = [0.00150831,0.00103604,0.000757637]

piA_1000par_Iterate = [0.0161127,0.0109085,0.00854578]
piA_1000par_Integrate = [0.00252162,0.00172483,0.00126874]

pi2_Iterate40 = [0.00108362,0.0108605,0.111]
piA_Iterate40 = [0.00150886,0.0161127,0.173282]
count = (0,1,2)
for i in count:
    pi2_Iterate40[i]= (pi2_Iterate40[i]*442)/1095
    piA_Iterate40[i]= (piA_Iterate40[i]*442)/1095


factor = [442,642,878]
count =0
for f in factor:
    pi2_1000par_Iterate[count]= (pi2_1000par_Iterate[count]*f)/1095
    pi2_1000par_Integrate[count]= (pi2_1000par_Integrate[count]*f)/1095
    piA_1000par_Iterate[count]= (piA_1000par_Iterate[count]*f)/1095
    piA_1000par_Integrate[count]= (piA_1000par_Integrate[count]*f)/1095
    count+=1

# %%
rcParams['figure.figsize'] = 8, 6
import matplotlib.lines as mlines

rcParams.update({'font.size': 12})


plt.xlabel("Number of Particles")
plt.ylabel("Execution Time(s)")
plt.title('Execution Time on 40% data removed, Rpi2 RpiA+')
# plt.scatter(x, y, s=area, alpha=0.5)
plt.plot((100,1000,10000), pi2_Iterate40,'r-',(100,1000,10000), piA_Iterate40,'-b')

blue_line = mlines.Line2D([], [], color='blue',
                          markersize=5,label='Rpi2')
red_line = mlines.Line2D([], [], color='red',
                          markersize=5, label='Rpi A+')
plt.legend(handles=[blue_line,red_line],loc=0)
plt.savefig('Pi2_vs_PiA.png')

plt.show()
